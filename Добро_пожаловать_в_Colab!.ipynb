# %% [markdown]
# <a href="https://colab.research.google.com/github/zarrinagt/lab1AIML/blob/main/%D0%94%D0%BE%D0%B1%D1%80%D0%BE_%D0%BF%D0%BE%D0%B6%D0%B0%D0%BB%D0%BE%D0%B2%D0%B0%D1%82%D1%8C_%D0%B2_Colab!.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1st problem

scores=[72,85,90,68,88]
print("Scores:",scores)
average=sum(scores)/len(scores)
highes_score=max(scores)
lowest_score=min(scores)

print("Average:", average)
print("Highest score:",max(scores))
print("Lowest score:",min(scores))
# Out:
# Scores: [72, 85, 90, 68, 88]
# Average: 80.6
# Highest score: 90
# Lowest score: 68

# %%
#2nd problem

study_hours=[1,2,3,4,5]
exam_scores=[50,55,65,70,80]
for h in range(len(study_hours)):
  print("Input:",study_hours[h],"hours -> Output:",exam_scores[h],"marks")
# Out:
# Input: 1 hours -> Output: 50 marks
# Input: 2 hours -> Output: 55 marks
# Input: 3 hours -> Output: 65 marks
# Input: 4 hours -> Output: 70 marks
# Input: 5 hours -> Output: 80 marks

# %%
#3rd problem

scores=[45,67,82,59]
def pass_fail(score):
  if score >=60:
    return "Pass"
  else:
    return "Fail"
for score in scores:
  result = pass_fail(score)
  print("Input: ",score," -> Output: ",result)
# Out:
# Input:  45  -> Output:  Fail
# Input:  67  -> Output:  Pass
# Input:  82  -> Output:  Pass
# Input:  59  -> Output:  Fail

# %%
#4th problem

sizes =[500,800, 1000, 1200]
prices = [50,80,100,130]

for i in range(len(sizes)):
 print("House size:",sizes[i], "Price:", prices[i])
positive_trend = True
for i in range(len(prices) - 1):
    if prices[i] >= prices[i + 1]:
        positive_trend = False
        break

if positive_trend:
    print("Positive trend")
# Out:
# House size: 500 Price: 50
# House size: 800 Price: 80
# House size: 1000 Price: 100
# House size: 1200 Price: 130
# Positive trend

# %%
#5 problem
study_hours = [2, 4, 6, 8]
scores = [55 , 65, 75, 85]
total_increase=0
for i in range(1, len(scores)):
  total_increase += scores[i] - scores[i - 1]

average_increase = total_increase /len(scores)

predicted_score = scores[-1] + average_increase
print("Predicted score for 10 hours of study:", predicted_score)
# Out:
# Predicted score for 10 hours of study: 92.5

# %%
#problem 6
scores = [35 , 58, 62, 74, 89, 45]
for score in scores:
    if score < 50:
        category = "Low"
    elif 50 <= score <= 70:
        category = "Medium"
    else:
        category = "High"

    print("Score:", score, "Category:",category)
# Out:
# Score: 35 Category: Low
# Score: 58 Category: Medium
# Score: 62 Category: Medium
# Score: 74 Category: High
# Score: 89 Category: High
# Score: 45 Category: Low

# %%
#problem 7
ages = [18 , 20, 22, 24, 26]
heights = [160 , 165 , 170 , 175 , 180]
print("Age and Height pairs:")
for i in range(len(ages)):
    print("Age:",ages[i], "Height:",heights[i])

average_age = sum(ages) / len(ages)
print("Average Age:",average_age, "years")

average_height = sum(heights) / len(heights)
print("Average Height:", average_height)
increasing = True
for i in range(len(heights) - 1):
    if heights[i] >= heights[i + 1]:
        increasing = False
        break

if increasing:
    print("Observation: Height appears to increase with age")
else:
    print("Observation: Height does not consistently increase with age")
# Out:
# Age and Height pairs:
# Age: 18 Height: 160
# Age: 20 Height: 165
# Age: 22 Height: 170
# Age: 24 Height: 175
# Age: 26 Height: 180
# Average Age: 22.0 years
# Average Height: 170.0
# Observation: Height appears to increase with age
